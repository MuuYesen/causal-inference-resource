# %% [markdown]
# ### 环境搭建

# %%
import pandas as pd

# %% [markdown]
# ### 数据读取

# %%
ce = pd.read_csv('result/ce.csv')
ce
# Out:
#            ce_1      ce_2
# 0      0.004535 -0.089250
# 1     -0.047464 -0.084024
# 2     -0.010784 -0.090442
# 3     -0.033144 -0.086452
# 4     -0.034393 -0.102575
# ...         ...       ...
# 41183 -0.016295 -0.102653
# 41184 -0.029018 -0.089552
# 41185 -0.031351 -0.099951
# 41186 -0.053527 -0.087488
# 41187 -0.029937 -0.081869
#
# [41188 rows x 2 columns]

# %%
ce_ct_all = pd.read_csv('result/ce_ct_all.csv')
ce_ct_all
# Out:
#            ce_1      ce_2
# 0      1.966838  2.969112
# 1     -2.267986 -1.110867
# 2      2.079099 -2.258838
# 3     -1.759406  2.179181
# 4      1.966838  2.746524
# ...         ...       ...
# 41183  2.761532  2.370868
# 41184 -1.872121  1.809046
# 41185 -2.057276  1.321972
# 41186 -0.259210  2.453821
# 41187 -2.057276  6.904345
#
# [41188 rows x 2 columns]

# %%
ce_dml_all = pd.read_csv('result/ce_dml_all.csv')
ce_dml_all
# Out:
#            ce_1      ce_2
# 0      0.284180  0.185547
# 1      0.015625  0.022461
# 2      0.073242 -0.090820
# 3      0.213867  0.045898
# 4      0.207031  0.189453
# ...         ...       ...
# 41183  0.120117  0.138672
# 41184  0.018555  0.029297
# 41185  0.074219  0.101562
# 41186  0.048828 -0.443359
# 41187  0.070312  0.070312
#
# [41188 rows x 2 columns]

# %% [markdown]
# ### 探索性分析

# %%
res_all = pd.concat([ce, ce_ct_all, ce_dml_all], axis=1)
res_all.columns = ['ce_1','ce_2','ce_ct_all_1','ce_ct_all_2','ce_dml_all_1','ce_dml_all_2']
res_all.hist(bins=100,figsize=(40, 30))
# Out:
# array([[<AxesSubplot:title={'center':'ce_1'}>,
#         <AxesSubplot:title={'center':'ce_2'}>],
#        [<AxesSubplot:title={'center':'ce_ct_all_1'}>,
#         <AxesSubplot:title={'center':'ce_ct_all_2'}>],
#        [<AxesSubplot:title={'center':'ce_dml_all_1'}>,
#         <AxesSubplot:title={'center':'ce_dml_all_2'}>]], dtype=object)

# %%
res_all.describe()
# Out:
#                ce_1          ce_2   ce_ct_all_1   ce_ct_all_2  ce_dml_all_1  \
# count  41188.000000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      -0.024056     -0.082099     -0.336097      1.471091      0.113057
# std        0.095112      0.102452      1.785684      1.537575      0.093868
# min       -3.105719     -3.067151     -6.035106     -8.588823     -2.038086
# 25%       -0.036708     -0.101255     -1.886809      1.101318      0.056641
# 50%       -0.030168     -0.091403     -1.029554      1.846117      0.113281
# 75%       -0.017059     -0.078796      1.721261      2.404170      0.168945
# max        3.790920      2.645136      6.396644      6.904345      1.608398
#
#        ce_dml_all_2
# count  41188.000000
# mean       0.045839
# std        0.135617
# min       -1.778320
# 25%       -0.011719
# 50%        0.064453
# 75%        0.130859
# max        1.205078

# %%
res_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ce_1          41188 non-null  float64
#  1   ce_2          41188 non-null  float64
#  2   ce_ct_all_1   41188 non-null  float64
#  3   ce_ct_all_2   41188 non-null  float64
#  4   ce_dml_all_1  41188 non-null  float64
#  5   ce_dml_all_2  41188 non-null  float64
# dtypes: float64(6)
# memory usage: 1.9 MB
