# %% [markdown]
# ### 环境搭建

# %%
import pandas as pd

# %% [markdown]
# ### 数据读取

# %%
ce = pd.read_csv('result/ce.csv')
ce
# Out:
#            ce_1      ce_2
# 0      0.004535 -0.089250
# 1     -0.047464 -0.084024
# 2     -0.010784 -0.090442
# 3     -0.033144 -0.086452
# 4     -0.034393 -0.102575
# ...         ...       ...
# 41183 -0.016295 -0.102653
# 41184 -0.029018 -0.089552
# 41185 -0.031351 -0.099951
# 41186 -0.053527 -0.087488
# 41187 -0.029937 -0.081869
#
# [41188 rows x 2 columns]

# %%
ce_ct_all = pd.read_csv('result/ce_ct_all.csv')
ce_ct_all
# Out:
#            ce_1      ce_2
# 0      1.966838  2.969112
# 1     -2.267986 -1.110867
# 2      2.079099 -2.258838
# 3     -1.759406  2.179181
# 4      1.966838  2.746524
# ...         ...       ...
# 41183  2.761532  2.370868
# 41184 -1.872121  1.809046
# 41185 -2.057276  1.321972
# 41186 -0.259210  2.453821
# 41187 -2.057276  6.904345
#
# [41188 rows x 2 columns]

# %%
ce_dml_all = pd.read_csv('result/ce_dml_all.csv')
ce_dml_all
# Out:
#            ce_1      ce_2
# 0      0.284180  0.185547
# 1      0.015625  0.022461
# 2      0.073242 -0.090820
# 3      0.213867  0.045898
# 4      0.207031  0.189453
# ...         ...       ...
# 41183  0.120117  0.138672
# 41184  0.018555  0.029297
# 41185  0.074219  0.101562
# 41186  0.048828 -0.443359
# 41187  0.070312  0.070312
#
# [41188 rows x 2 columns]

# %% [markdown]
# ### 探索性分析

# %%
tmp = pd.concat([ce, ce_ct_all, ce_dml_all], axis=1)
tmp.columns = ['ce_1','ce_2','ce_ct_all_1','ce_ct_all_2']
tmp.hist(bins=100,figsize=(40, 30))
# Out:
# array([[<AxesSubplot:title={'center':'ce_1'}>,
#         <AxesSubplot:title={'center':'ce_2'}>],
#        [<AxesSubplot:title={'center':'ce_ct_all_1'}>,
#         <AxesSubplot:title={'center':'ce_ct_all_2'}>]], dtype=object)

# %%
ce_dml_all.hist(bins=100,figsize=(40, 30))
# Out:
# array([[<AxesSubplot:title={'center':'ce_1'}>,
#         <AxesSubplot:title={'center':'ce_2'}>]], dtype=object)
